# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

url =  "https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops"

response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")

# %%
dom = etree.HTML(str(soup))
rows = dom.xpath('//div[@class="col-md-4 col-xl-4 col-lg-4"]')
title = dom.xpath('//a[@class="title"]/@title')
price = dom.xpath('//h4[@class="float-end price card-title pull-right"]/text()')
des = dom.xpath('//p[@class="description card-text"]/text()')

# %%
for i in range(len(rows)):
    print(f"name of prod: {title[i]}\n\
price: {price[i]}\n\
description: {des[i]}")
    print("\n\n")
# Out:
# name of prod: Asus VivoBook X441NA-GA190
# price: $295.99
# description: Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd
#
#
#
# name of prod: Prestigio SmartBook 133S Dark Grey
# price: $299.00
# description: Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam
#
#
#
# name of prod: Prestigio SmartBook 133S Gold
# price: $299.00
# description: Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam
#
#
#
# name of prod: Aspire E1-510
# price: $306.99
# description: 15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
#
#
#
# name of prod: Lenovo V110-15IAP
# price: $321.94
# description: Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home
#
#
#
# name of prod: Lenovo V110-15IAP
# price: $356.49
# ...
